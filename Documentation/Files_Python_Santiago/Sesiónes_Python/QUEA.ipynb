# %%
import pandas as pd
import os

# %%
df = pd.read_excel('C:/OTMX/Inputs/2024-044/Other Files/EDC_QUALITAS.xlsx')

df = df.dropna(subset=['Unnamed: 8'])

df = df[df['Unnamed: 8'].str.strip() != ""]
df = df[df['Unnamed: 8'].str.strip() != "MONEDA NAL"]
df = df[df['Unnamed: 8'] != 0]

df.columns = df.iloc[1,]

df = df[df['AGENTE'].str.strip() != "AGENTE"]

#df['Unnamed: 8'] = df['Unnamed: 8'].str.strip()
#df = df[df['Unnamed: 8'].str.strip().notnull()]


#df
# Out:
# 9                    FECHA      POLIZA ENDOSO     RECIBO                SERIE  \
# 1                      NaN         NaN    NaN        NaN                  NaN
# 12     2024-04-11 00:00:00  2661075048      0  247946008  2024-01-01 00:00:00
# 13     2024-04-18 00:00:00  2700288274      0  203561527  2024-05-03 00:00:00
# 14     2024-04-18 00:00:00  2700288313      0  203562193  2024-04-03 00:00:00
# 15     2024-04-18 00:00:00  2700288353      0  203562757  2024-05-03 00:00:00
# ...                    ...         ...    ...        ...                  ...
# 11117  2024-04-11 00:00:00  2661074865      0  247873261  2024-01-01 00:00:00
# 11118  2024-04-11 00:00:00  3200587556      0  247465163  2024-01-01 00:00:00
# 11119  2024-04-11 00:00:00  3200587583      0  247842474  2024-01-01 00:00:00
# 11167                  NaN         NaN    NaN        NaN                  NaN
# 11178  2024-04-11 00:00:00  2661074701      0  247806779  2024-04-01 00:00:00
#
# ...

# %%
df['AGENCIA'] = df['AGENTE'].where(df['AGENTE'].str.startswith('AGENCIA NUM:')).ffill()

# %%
df = df.dropna(subset=['POLIZA'])

# %%
df['AGENCIA'] = df['AGENCIA'].str.replace("AGENCIA NUM: ","")
# Out:
# C:\Users\u1165269\AppData\Local\Temp\ipykernel_49944\2679498607.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['AGENCIA'] = df['AGENCIA'].str.replace("AGENCIA NUM: ","")
